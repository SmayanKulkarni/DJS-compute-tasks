# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#df = pd.read_csv("/home/smayan/Desktop/Smayan_Kulkarni_Compute/DJS-compute-tasks/Data/data.csv")
df = pd.read_csv("/workspaces/DJS-compute-tasks/Data/data.csv")

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
df.head(5)
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2     200389  https://sofifa.com/player/200389/jan-oblak/210002
# 3     188545  https://sofifa.com/player/188545/robert-lewand...
# 4     190871  https://sofifa.com/player/190871/neymar-da-sil...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   33  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   35  1985-02-05
# 2           J. Oblak                            Jan Oblak   27  1993-01-07
# 3     R. Lewandowski                   Robert Lewandowski   31  1988-08-21
# 4          Neymar Jr        Neymar da Silva Santos Júnior   28  1992-02-05
#
#    height_cm  weight_kg nationality            club_name  \
# 0        170         67   Argentina         FC Barcelona
# ...

# %%
df.describe()
# Out:
#            sofifa_id           age     height_cm     weight_kg   league_rank  \
# count   18944.000000  18944.000000  18944.000000  18944.000000  18719.000000
# mean   226242.402872     25.225823    181.190773     75.016628      1.357070
# std     27171.091056      4.697354      6.825672      7.057347      0.739327
# min        41.000000     16.000000    155.000000     50.000000      1.000000
# 25%    210030.500000     21.000000    176.000000     70.000000      1.000000
# 50%    232314.500000     25.000000    181.000000     75.000000      1.000000
# 75%    246760.250000     29.000000    186.000000     80.000000      1.000000
# max    258970.000000     53.000000    206.000000    110.000000      4.000000
#
#             overall     potential     value_eur       wage_eur  \
# count  18944.000000  18944.000000  1.894400e+04   18944.000000
# mean      65.677787     71.086729  2.224813e+06    8675.852513
# std        7.002278      6.109985  5.102486e+06   19654.774894
# ...

# %%
df.shape
# Out:
# (18944, 106)

# %%
df.drop('short_name',axis=1,inplace=True)
df.rename(columns={'long_name':'name'},inplace=True)

# %%
df['potential']
# Out:
# 0        93
# 1        92
# 2        93
# 3        91
# 4        91
# 5        91
# 6        95
# 7        93
# 8        91
# 9        91
# 10       90
# 11       90
# 12       90
# 13       89
# 14       89
# 15       89
# 16       89
# 17       89
# 18       91
# 19       90
# 20       90
# 21       89
# 22       89
# 23       88
# 24       88
# 25       88
# 26       88
# 27       88
# 28       93
# 29       92
# 30       90
# 31       90
# 32       89
# 33       89
# 34       88
# 35       87
# 36       87
# 37       87
# 38       87
# 39       87
# 40       87
# 41       87
# 42       87
# 43       87
# 44       87
# 45       87
# 46       87
# 47       87
# 48       88
# 49       87
# 50       87
# 51       86
# 52       86
# 53       86
# 54       86
# 55       86
# 56       86
# 57       86
# 58       86
# 59       86
# 60       86
# 61       86
# 62       93
# 63       92
# 64       92
# 65       91
# 66       90
# 67       90
# 68       89
# 69       89
# 70       89
# ...

# %%
df['international_reputation'].value_counts()
# Out:
# international_reputation
# 1    17593
# 2     1017
# 3      285
# 4       43
# 5        6
# Name: count, dtype: int64

# %%
df['international_reputation'].unique()
# Out:
# array([5, 3, 4, 2, 1])

# %%
df['skill_moves'].unique()
# Out:
# array([4, 5, 1, 2, 3])

# %%
df['work_rate'].unique()
# Out:
# array(['Medium/Low', 'High/Low', 'Medium/Medium', 'High/Medium',
#        'High/High', 'Medium/High', 'Low/High', 'Low/Medium', 'Low/Low'],
#       dtype=object)

# %%
df['body_type']
# Out:
# 0                       Messi
# 1                  C. Ronaldo
# 2        PLAYER_BODY_TYPE_259
# 3        PLAYER_BODY_TYPE_276
# 4                      Neymar
# 5        PLAYER_BODY_TYPE_321
# 6        PLAYER_BODY_TYPE_343
# 7        PLAYER_BODY_TYPE_262
# 8        PLAYER_BODY_TYPE_314
# 9        PLAYER_BODY_TYPE_312
# 10       PLAYER_BODY_TYPE_313
# 11              Mohamed Salah
# 12                   Courtois
# 13       PLAYER_BODY_TYPE_322
# 14       PLAYER_BODY_TYPE_352
# 15                     Normal
# 16       PLAYER_BODY_TYPE_273
# 17       PLAYER_BODY_TYPE_358
# 18       PLAYER_BODY_TYPE_325
# 19       PLAYER_BODY_TYPE_320
# 20                       Lean
# 21       PLAYER_BODY_TYPE_368
# 22       PLAYER_BODY_TYPE_342
# 23       PLAYER_BODY_TYPE_300
# 24                     Normal
# 25       PLAYER_BODY_TYPE_356
# 26       PLAYER_BODY_TYPE_336
# 27       PLAYER_BODY_TYPE_283
# 28                     Normal
# 29       PLAYER_BODY_TYPE_316
# 30                       Lean
# ...

# %%
df.isnull().sum()
# Out:
# sofifa_id                         0
# player_url                        0
# name                              0
# age                               0
# dob                               0
# height_cm                         0
# weight_kg                         0
# nationality                       0
# club_name                       225
# league_name                     225
# league_rank                     225
# overall                           0
# potential                         0
# value_eur                         0
# wage_eur                          0
# player_positions                  0
# preferred_foot                    0
# international_reputation          0
# weak_foot                         0
# skill_moves                       0
# work_rate                         0
# body_type                         0
# real_face                         0
# release_clause_eur              995
# player_tags                   17536
# team_position                   225
# ...

# %%
columns_checking = ['player_tags','loaned_from','nation_position','nation_jersey_number','defending_marking','gk_diving','player_traits','club_name','league_name','league_rank','release_clause_eur','team_position',
                    'team_jersey_number','joined','contract_valid_until']

def null_pecentage(df, columns):
    result={}
    for col in columns:
        if col in df.columns:
            null_percentage = (df[col].isnull().sum() / len(df)) * 100
            result[col] = round(null_percentage, 2)
        else:
            result[col] = "Column not found"
    return result

null_percentage = null_pecentage(df, columns_checking)

for column, percentage in null_percentage.items():
    if isinstance(percentage, float):
        print(f"{column}: {percentage}%")
    else:
        print(f"{column}: {percentage}")
# Out:
# player_tags: 92.57%
# loaned_from: 96.0%
# nation_position: 94.05%
# nation_jersey_number: 94.05%
# defending_marking: 100.0%
# gk_diving: 89.0%
# player_traits: 56.11%
# club_name: 1.19%
# league_name: 1.19%
# league_rank: 1.19%
# release_clause_eur: 5.25%
# team_position: 1.19%
# team_jersey_number: 1.19%
# joined: 5.19%
# contract_valid_until: 1.19%

# %%
sns.barplot(data=null_percentage, x=null_percentage.values(), y=null_percentage.keys(), palette='viridis', hue=null_percentage.keys()).set(title="Percentage of NaN Values", xlabel="Percentage (%)", ylabel="Features")
plt.show()

# %%
df.shape
# Out:
# (18944, 105)

# %%
df2= df.drop(columns=['player_tags','loaned_from','nation_position','nation_jersey_number','defending_marking'], axis=1)

# %%
df2.dropna(subset=['club_name','league_name','league_rank','release_clause_eur','team_position',
                    'team_jersey_number','joined','contract_valid_until'], inplace=True)

# %%
df2.head(5)
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2     200389  https://sofifa.com/player/200389/jan-oblak/210002
# 3     188545  https://sofifa.com/player/188545/robert-lewand...
# 4     190871  https://sofifa.com/player/190871/neymar-da-sil...
#
#                                   name  age         dob  height_cm  weight_kg  \
# 0       Lionel Andrés Messi Cuccittini   33  1987-06-24        170         67
# 1  Cristiano Ronaldo dos Santos Aveiro   35  1985-02-05        187         83
# 2                            Jan Oblak   27  1993-01-07        188         87
# 3                   Robert Lewandowski   31  1988-08-21        184         80
# 4        Neymar da Silva Santos Júnior   28  1992-02-05        175         68
#
#   nationality            club_name             league_name  league_rank  \
# ...

# %%
df2.shape
# Out:
# (17949, 100)

# %%
df2.dtypes
# Out:
# sofifa_id                       int64
# player_url                     object
# name                           object
# age                             int64
# dob                            object
# height_cm                       int64
# weight_kg                       int64
# nationality                    object
# club_name                      object
# league_name                    object
# league_rank                   float64
# overall                         int64
# potential                       int64
# value_eur                       int64
# wage_eur                        int64
# player_positions               object
# preferred_foot                 object
# international_reputation        int64
# weak_foot                       int64
# skill_moves                     int64
# work_rate                      object
# body_type                      object
# real_face                      object
# release_clause_eur            float64
# team_position                  object
# ...

# %%
temp = df.copy()
temp.head(5)
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2     200389  https://sofifa.com/player/200389/jan-oblak/210002
# 3     188545  https://sofifa.com/player/188545/robert-lewand...
# 4     190871  https://sofifa.com/player/190871/neymar-da-sil...
#
#                                   name  age         dob  height_cm  weight_kg  \
# 0       Lionel Andrés Messi Cuccittini   33  1987-06-24        170         67
# 1  Cristiano Ronaldo dos Santos Aveiro   35  1985-02-05        187         83
# 2                            Jan Oblak   27  1993-01-07        188         87
# 3                   Robert Lewandowski   31  1988-08-21        184         80
# 4        Neymar da Silva Santos Júnior   28  1992-02-05        175         68
#
#   nationality            club_name             league_name  league_rank  \
# ...

# %%
df=df2.copy()
df=temp.copy()
del temp

# %%
df[['year','month','date']]=df['dob'].str.split('-', expand=True)
df.drop('dob', axis=1,inplace=True)

# %%
df.head(5)
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2     200389  https://sofifa.com/player/200389/jan-oblak/210002
# 3     188545  https://sofifa.com/player/188545/robert-lewand...
# 4     190871  https://sofifa.com/player/190871/neymar-da-sil...
#
#                                   name  age  height_cm  weight_kg nationality  \
# 0       Lionel Andrés Messi Cuccittini   33        170         67   Argentina
# 1  Cristiano Ronaldo dos Santos Aveiro   35        187         83    Portugal
# 2                            Jan Oblak   27        188         87    Slovenia
# 3                   Robert Lewandowski   31        184         80      Poland
# 4        Neymar da Silva Santos Júnior   28        175         68      Brazil
#
#              club_name             league_name  league_rank  overall  \
# ...

# %%
df['body_type'].unique()
# Out:
# array(['Messi', 'C. Ronaldo', 'PLAYER_BODY_TYPE_259',
#        'PLAYER_BODY_TYPE_276', 'Neymar', 'PLAYER_BODY_TYPE_321',
#        'PLAYER_BODY_TYPE_343', 'PLAYER_BODY_TYPE_262',
#        'PLAYER_BODY_TYPE_314', 'PLAYER_BODY_TYPE_312',
#        'PLAYER_BODY_TYPE_313', 'Mohamed Salah', 'Courtois',
#        'PLAYER_BODY_TYPE_322', 'PLAYER_BODY_TYPE_352', 'Normal',
#        'PLAYER_BODY_TYPE_273', 'PLAYER_BODY_TYPE_358',
#        'PLAYER_BODY_TYPE_325', 'PLAYER_BODY_TYPE_320', 'Lean',
#        'PLAYER_BODY_TYPE_368', 'PLAYER_BODY_TYPE_342',
#        'PLAYER_BODY_TYPE_300', 'PLAYER_BODY_TYPE_356',
#        'PLAYER_BODY_TYPE_336', 'PLAYER_BODY_TYPE_283',
#        'PLAYER_BODY_TYPE_316', 'PLAYER_BODY_TYPE_319',
#        'PLAYER_BODY_TYPE_311', 'PLAYER_BODY_TYPE_310',
#        'PLAYER_BODY_TYPE_365', 'PLAYER_BODY_TYPE_374',
#        'PLAYER_BODY_TYPE_345', 'PLAYER_BODY_TYPE_253',
#        'PLAYER_BODY_TYPE_305', 'PLAYER_BODY_TYPE_266',
# ...

# %%
df['height_m']  = df['height_cm']/100

# %%
df.drop('height_cm', axis=1,inplace=True)

# %%
df['bmi'] = df['weight_kg']/(df['height_m']**2)

# %%
df['bmi']
# Out:
# 0        23.183391
# 1        23.735308
# 2        24.615211
# 3        23.629490
# 4        22.204082
# 5        21.366869
# 6        23.040020
# 7        24.307244
# 8        24.698650
# 9        24.944492
# 10       22.530612
# 11       23.183673
# 12       24.241812
# 13       23.388687
# 14       24.220227
# 15       23.666910
# 16       24.698650
# 17       24.543462
# 18       24.332277
# 19       23.875433
# 20       23.566632
# 21       25.181077
# 22       23.939481
# 23       24.698650
# 24       22.694019
# 25       24.163265
# 26       25.451114
# 27       24.801587
# 28       23.456790
# 29       21.296296
# 30       21.534908
# 31       23.795526
# 32       22.068809
# 33       20.199470
# 34       21.383942
# 35       24.307244
# 36       23.200543
# 37       25.963048
# 38       22.309356
# 39       21.296296
# 40       23.668639
# 41       22.877406
# 42       21.276000
# 43       24.835646
# 44       23.374726
# 45       23.566632
# 46       23.291230
# ...

# %%
def bodtype(bmi):
    if bmi < 18.5:
        return 'skinny'
    elif 18.5 <= bmi < 20:
        return 'lean'
    elif 20 <= bmi < 24.9:
        return 'muscular'
    elif 24.9 <= bmi < 26.5:
        return 'stocky'
    else:
        return 'obese'

# %%
df['Body_Type'] = df['bmi'].apply(bodtype)
df.drop('body_type', axis=1, inplace=True)

# %%
df.head(5)
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2     200389  https://sofifa.com/player/200389/jan-oblak/210002
# 3     188545  https://sofifa.com/player/188545/robert-lewand...
# 4     190871  https://sofifa.com/player/190871/neymar-da-sil...
#
#                                   name  age  weight_kg nationality  \
# 0       Lionel Andrés Messi Cuccittini   33         67   Argentina
# 1  Cristiano Ronaldo dos Santos Aveiro   35         83    Portugal
# 2                            Jan Oblak   27         87    Slovenia
# 3                   Robert Lewandowski   31         80      Poland
# 4        Neymar da Silva Santos Júnior   28         68      Brazil
#
#              club_name             league_name  league_rank  overall  \
# 0         FC Barcelona  Spain Primera Division          1.0       93
# ...

# %%
df['Body_Type'].unique()
# Out:
# array(['muscular', 'stocky', 'lean', 'obese', 'skinny'], dtype=object)

# %%
df['potential']=df['potential'].astype(int)

# %%
sns.boxplot(data=df,y = 'age',color='lightgreen').set(title='Distribution of Player Age')
plt.show()

# %%
sns.scatterplot(data=df, x='age', y='value_eur', color='lightgreen').set(title='Age vs. Value in EU')
plt.show()

# %%
sns.scatterplot(data=df, x='age', y='wage_eur', color='lightgreen').set(title='Age vs. Wage in EU')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(20, 7))
df_plot = df.sort_values(by='year')
sns.lineplot(x='year', y='potential', data=df_plot, marker='o')
plt.title('Points Change Over Years')
plt.xlabel('Year of birth')
plt.ylabel('Potential')
plt.grid(True)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(20, 7))
df_plot = df.sort_values(by='year')
sns.lineplot(x='year', y='overall', data=df_plot, marker='o')
plt.title('Points Change Over Years')
plt.xlabel('Year of birth')
plt.ylabel('Overall')
plt.grid(True)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(20, 7))
sns.lineplot(x='year', y='value_eur', data=df, marker='o')
plt.title('Points Change Over Years')
plt.xlabel('Year of birth')
plt.ylabel('Overall')
plt.grid(True)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(5, 7))

sns.barplot(x='preferred_foot', y='shooting', data=df)
plt.title('Preferred foot vs Shooting ability')
plt.xlabel('Preferred Foot')
plt.ylabel('Shooting ability')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(9, 7))

sns.barplot(x='Body_Type', y='defending', data=df)
plt.title('Preferred foot vs Shooting ability')
plt.xlabel('Preferred Foot')
plt.ylabel('Shooting ability')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(9, 7))

sns.barplot(x='Body_Type', y='shooting', data=df)
plt.title('Preferred foot vs Shooting ability')
plt.xlabel('Preferred Foot')
plt.ylabel('Shooting ability')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(9, 7))

sns.barplot(x='Body_Type', y='physic', data=df)
plt.title('Preferred foot vs Shooting ability')
plt.xlabel('Preferred Foot')
plt.ylabel('Shooting ability')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(9, 7))

sns.barplot(x='Body_Type', y='pace', data=df)
plt.title('Preferred foot vs Shooting ability')
plt.xlabel('Preferred Foot')
plt.ylabel('Shooting ability')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(9, 7))

sns.barplot(x='Body_Type', y='dribbling', data=df)
plt.title('Preferred foot vs Shooting ability')
plt.xlabel('Preferred Foot')
plt.ylabel('Shooting ability')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(90, 7))

sns.barplot(x='league_name', y='international_reputation', data=df)
plt.title('Preferred foot vs Shooting ability')
percent = (96 *df['international_reputation'].mean() )/ 100
plt.axhline(percent, color='r', linestyle='--', label='96%')
plt.xlabel('Preferred Foot')
plt.ylabel('Shooting ability')
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(90, 7))

sns.barplot(x='nationality', y='international_reputation', data=df)
plt.title('Preferred foot vs Shooting ability')
percent = (96 *df['international_reputation'].mean() )/ 100
plt.axhline(percent, color='r', linestyle='--', label='96%')
plt.xlabel('Preferred Foot')
plt.ylabel('Shooting ability')
plt.xticks(rotation=45, ha='right')
plt.show()
